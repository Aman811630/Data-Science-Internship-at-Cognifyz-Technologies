# %% [markdown]
# <a href="https://colab.research.google.com/github/Aman811630/Data-Science-Internship-at-Cognifyz-Technologies/blob/main/Conifyz_Data_Science_Internship_By_Aman_Singh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Internship at Cognifyz Technologies
#
# ---
#
#
#
# ---

# %% [markdown]
# ![Screenshot (95).png](data:image/png;base64,...)

# %% [markdown]
# ## Cognifyz : Data Science Internship
# ### Intern Name :- Aman Singh

# %% [markdown]
# # Level 01 :
#
# ---
#
#
# ## Task 01 :- Data Exploration and Preprocessing
#
# ---
#
#
# ### Explore the dataset and identify the number of rows and columns.Check for missing values in each column and handle them accordingly. Perform data type conversion if necessary. Analyze the distribution of the target variable ("Aggregate rating") and identify any class imbalances.

# %%
# importing lib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # Visualization Libraries
# %matplotlib inline
import seaborn as sns

# Ignore all warnings
import warnings

warnings.filterwarnings('ignore')

# %%
# loading data & copy  dataset
dataset=pd.read_csv("/content/drive/MyDrive/resturant.csv")
df=dataset.copy()
df.head(10)
# Out:
#    Restaurant ID                           Restaurant Name  Country Code  \
# 0        6317637                          Le Petit Souffle           162
# 1        6304287                          Izakaya Kikufuji           162
# 2        6300002                    Heat - Edsa Shangri-La           162
# 3        6318506                                      Ooma           162
# 4        6314302                               Sambo Kojin           162
# 5       18189371                              Din Tai Fung           162
# 6        6300781                                Buffet 101           162
# 7        6301290                                   Vikings           162
# 8        6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9        6314987                                  Locavore           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %%
# Checking sahpe & Size of dataset

df.size, df.shape
# Out:
# (200571, (9551, 21))

# %%
# Dataset Duplicate Value Count

dup = df.duplicated().sum()
print(f'number of duplicated rows are {dup}')
# Out:
# number of duplicated rows are 0

# %%
# missing or NaN values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Visualizing the missing values
# Checking Null Value by Plotting Heatmap

# Set the plot size
plt.figure(figsize = (8,5))

# Create the figure object
sns.heatmap(df.isnull().corr(), vmin=-1, annot= True)

# Setting  labels
plt.xlabel('Name of columns', fontsize=11)
plt.ylabel('Name of columns', fontsize=10)
plt.title('Places of missing values in Dataset', fontsize=12)
plt.show() # To show

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# ### Data type conversion not neded it's look fine

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code      City  \
# 9546        5915730               Naml۱ Gurme           208  Istanbul
# 9547        5908749              Ceviz A��ac۱           208  Istanbul
# 9548        5915807                     Huqqa           208  Istanbul
# 9549        5916112               A���k Kahve           208  Istanbul
# 9550        5927402  Walter's Coffee Roastery           208  Istanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %% [markdown]
# ## Distribution of The Target Variable
# Here I aim to check how my target variable ("Aggregate rating") is distributed...

# %%
# Distribution of the target variable ("Aggregate rating") and identify class imbalance
target_counts = df['Aggregate rating'].value_counts()
print("Distribution of target variable:- ")
print(target_counts)
# Out:
# Distribution of target variable:-
# Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64

# %%
# Distribution of the target variable ("Aggregate rating") and identify class imbalance
# PLOTTING IT FOR VISULAIZATION

sns.set_style('whitegrid')
sns.distplot(df["Aggregate rating"], kde = False, color ='GREEN')
# Out:
# <Axes: xlabel='Aggregate rating'>

# %% [markdown]
# ## Observations & Insights I Get till Now...
#
# ---

# %% [markdown]
# ## What did i found from the level 1 (task 1)?
#
# *    The Restuarant dataset consists of various restuarants information of different cities. Includes information such as restaurant name, city,
# address, locality, cuisines, rating and price range, among other things.
#
# *   There are 9551 rows and 21 columns provided in the dataset.
#
# *   Null values are only present in cuisines.
# *   Distribution of the target variable ("Aggregate rating") well balanced.
#
#
#
# *   Data type conversion not reqired

# %% [markdown]
# ## Task 02: Descriptive Analysis
#
# ---
#
#
#
# ### Calculate basic statistical measures (mean, median, standard deviation, etc.) for numerical columns. Explore the distribution of categorical variables like "Country Code, "City" and "Cuisines". Identify the top cuisines and cities with the highest number of restaurants.

# %% [markdown]
# ### Now its time for Statistical Measures for Numerical Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# # Basic statistical measures  for Numerical Columns are :-
#
# *   Mean
# *   Median
#
# *   Standard Deviation

# %%
# Select Numerical Columns

numeric_columns = df.select_dtypes(include=['int', 'float'])

numeric_columns.head()
# Out:
#    Restaurant ID  Country Code   Longitude   Latitude  Average Cost for two  \
# 0        6317637           162  121.027535  14.565443                  1100
# 1        6304287           162  121.014101  14.553708                  1200
# 2        6300002           162  121.056831  14.581404                  4000
# 3        6318506           162  121.056475  14.585318                  1500
# 4        6314302           162  121.057508  14.584450                  1500
#
#    Price range  Aggregate rating  Votes
# 0            3               4.8    314
# 1            3               4.5    591
# 2            4               4.4    270
# 3            4               4.9    365
# 4            4               4.8    229

# %%
# Calculate basic statistical measures using .describe()
summary_stats = numeric_columns.describe()
summary_stats
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# Importng Stats lib...

import math
import statistics
import scipy.stats

# %% [markdown]
# ### Individual statistics

# %%
# Calculate mean for numerical columns
mean = numeric_columns.mean()
mean
# Out:
# Restaurant ID           9.051128e+06
# Country Code            1.836562e+01
# Longitude               6.412657e+01
# Latitude                2.585438e+01
# Average Cost for two    1.199211e+03
# Price range             1.804837e+00
# Aggregate rating        2.666370e+00
# Votes                   1.569097e+02
# dtype: float64

# %%
# Calculate median for numerical columns

median = numeric_columns.median()
median
# Out:
# Restaurant ID           6.004089e+06
# Country Code            1.000000e+00
# Longitude               7.719196e+01
# Latitude                2.857047e+01
# Average Cost for two    4.000000e+02
# Price range             2.000000e+00
# Aggregate rating        3.200000e+00
# Votes                   3.100000e+01
# dtype: float64

# %%
# Calculate standard deviation for numerical columns
std_dev = numeric_columns.std()
std_dev
# Out:
# Restaurant ID           8.791521e+06
# Country Code            5.675055e+01
# Longitude               4.146706e+01
# Latitude                1.100794e+01
# Average Cost for two    1.612118e+04
# Price range             9.056088e-01
# Aggregate rating        1.516378e+00
# Votes                   4.301691e+02
# dtype: float64

# %% [markdown]
# ## Distribution of Categorical Variables

# %% [markdown]
# **Distribution of categorical variables like 'Country Code', 'City', and 'Cuisines'**

# %% [markdown]
# ## Count Plot Visualization Code for Country Codes

# %%
# Count Plot Visualization Code for Country Codes
# Set plot size
plt.figure(figsize=(7, 4))

# Create the figure object
sns.countplot(x = df['Country Code'],color = 'green')

# Set Labels
plt.xlabel('Country Codes')
plt.ylabel('Number of Restaurants')
plt.title('Distribution of Restaurants by Country Codes')

# Display Chart
plt.show()

# %% [markdown]
# ## Count Plot Visualization Code for Country Codes

# %%
# Set plot size
plt.figure(figsize=(7, 4))

# Create the figure object

sns.countplot(y = df['City'], order=df.City.value_counts().iloc[:20].index,color= 'salmon')

# Set Labels
plt.xlabel('Number of Restaurants')
plt.ylabel('City')
plt.title('Top 20 Cities with Highest Number of Restaurants')

# Display Chart
plt.show()

# %% [markdown]
# ## Count Plot Visualization Code for Cuisines

# %%
# Set plot size
plt.figure(figsize=(8, 5))

# Create the figure object
# There are many cuisine names present in the data, so i select only the top 10 cuisines
sns.countplot(y = df['Cuisines'], order=df.Cuisines.value_counts().iloc[:20].index, color = 'yellow')

# Set Labels
plt.xlabel('Number of Restaurants')
plt.ylabel('Name of Cuisines')
plt.title('Top 20 Cuisines with Highest Number of Restaurants')

# Display Chart
plt.show()

# %% [markdown]
# ### Top cuisines and cities with the highest number of restaurants

# %%
# Identify the top 15 cuisines
top_cuisines = df['Cuisines'].value_counts().head(15)

# Display the results
print("Top 15 Cuisines with Highest Number of Restaurants:")
print(top_cuisines)
# Out:
# Top 15 Cuisines with Highest Number of Restaurants:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Pizza, Fast Food                  131
# Chinese, Fast Food                118
# Mithai, Street Food               116
# South Indian                      112
# Bakery, Fast Food                 108
# Name: count, dtype: int64

# %%
# use pie chart to viulaize top 15 cusines
plt.figure(figsize=(10, 5))
df['Cuisines'].value_counts().head(15).plot(kind='pie',autopct='%.0f%%')

plt.xlabel('Name of Cuisines')
plt.title('Top 15 Cuisines with Highest Number of Restaurants')

# Display Chart
plt.show()

# %%
# Identify the top 10 cities
top_cities = df['City'].value_counts().head(15)

# Display the results
print("Top 15 Cities with Highest Number of Restaurants:")
print(top_cities)
# Out:
# Top 15 Cities with Highest Number of Restaurants:
# City
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
# Bhubaneshwar        21
# Amritsar            21
# Ahmedabad           21
# Lucknow             21
# Guwahati            21
# Ludhiana            20
# Rest of Hawaii      20
# Kochi               20
# Kolkata             20
# Pocatello           20
# Name: count, dtype: int64

# %%
# use horizontal bar chart to visualize

plt.figure(figsize=(10, 5))
df['City'].value_counts().head(15).plot(kind='barh',color='red')
plt.ylabel('Name of Cities')
plt.xlabel('Number of Restaurants')
plt.title('Top 15 Cuisines with Highest Number of Restaurants')

# Display Chart
plt.show()

# %% [markdown]
# ## Observations & Insights I Get till Now...
#
# ---
#
#
#
#
# ## What did i found from the level 1 (task 2)?
#
#
# *   Found the mean, median, mode values and other statistical measures for the numerical columns like 'Restaurant ID', 'Longitude', 'Latitude', 'Price range', etc.
# *   Country code 1 and 216 are with highest number of restaurants.
#
#
# *   New Delhi, Gurgaon and Noida are in top with highest number of restaurants.
# *   North Indian and Chinese cuisine are in top with highest number of restaurants.

# %% [markdown]
# # Task 03: Geospatial Analysis
#
# ---
#
# ### Visualize the locations of restaurants on a map using latitude and longitude information. Analyze the distribution of restaurants across different cities or countries. Determine if there is any correlation between the restaurant's location and its rating.

# %% [markdown]
# ## Locations of restaurants on a map using latitude and longitude information

# %%
# Import the necessary libraries
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

# %%
# Create Point geometry from latitude and longitude using Shapely lib
df['geometry'] = df.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)
gdf = gpd.GeoDataFrame(df , geometry= gpd.points_from_xy(df.Longitude , df.Latitude))

# Create a base map of the world using Geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Create a map that fits the screen and plots the restaurant locations


# The "continent" column is used for coloring and a legend is displayed

gdf.plot(ax=world.plot("continent", legend = True, figsize=(15, 10)), marker='o', markersize=15,color ='red')

# Show the map
plt.title('Locations of Restaurants on a Map')
plt.show()

# %% [markdown]
# ## Distribution of restaurants across different cities or countries

# %%
# Set plot size
plt.figure(figsize=(8, 5))

# Create the figure object
# There are many cities names present in the data, so i select only the top 15 cities

sns.countplot(y = df['City'], order=df.City.value_counts().iloc[:15].index,color ="brown")

# Set Labels
plt.xlabel('Number of Restaurants')
plt.ylabel('Name of Cities')
plt.title('Distribution of Restaurants Across Cities')

# Display Chart
plt.show()

# %% [markdown]
# ## Checking correlation between the restaurant's location and its rating

# %%
# Set plot size
plt.figure(figsize=(8, 4))

# Calculate the correlation between latitude, longitude, and ratings
correlation_matrix = df[['Latitude', 'Longitude', 'Aggregate rating']].corr()

# Create a heatmap to visualize the correlation
sns.heatmap(correlation_matrix, annot=True, fmt=".2f")

# Set Title
plt.title("Correlation Between Restaurant's Location and Rating")

# Display Chart
plt.show()

# %% [markdown]
# ## Observations & Insights I Get till Now...
#
#
# ---
#
#
# ### What did i found from the level 1 (task 3)?
#
# * North America and Asia(mainly India) have the most number of restaurants.
# Followed by Oceania and others.
# New Delhi have the most number of restaurants. Followed by Gurgaon, Noida and Faridabad.
# There is no correlation between Latitude and Rating. But, Longitude and Rating are negatively correlated.

# %% [markdown]
# # ***`Level 01 All Tasks Conclusion :-`***
#
# ---
#
#
#
# ---

# %% [markdown]
# * The dataset includes restaurant details across various cities with 9,551 rows and 21 columns. Minimal null values (9) were found only in the 'Cuisines' column. No duplicates exist, and data type conversion wasn't needed. The 'Aggregate rating' distribution is well-balanced.
#
# * Key statistical measures for numerical columns were identified. Country codes 1 and 216 have the most restaurants. New Delhi, Gurgaon, and Noida are top cities with the highest restaurant counts. North Indian and Chinese cuisines are most popular.
#
# * North America and Asia (mainly India) have the most number of restaurants. New Delhi leads in the number of restaurants, followed by Gurgaon, Noida, and Faridabad. Latitude and rating show no correlation, while longitude and rating are negatively correlated. These insights offer a comprehensive analysis of the restaurant dataset reveals key data characteristics, descriptive insights, and geospatial patterns, informs further analysis.

# %% [markdown]
# ![Screenshot (96).png](data:image/png;base64,...)
